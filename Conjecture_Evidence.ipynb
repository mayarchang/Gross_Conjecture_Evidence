# %%
load('cubic.sage')

# %%
# Compute the ratio C from the Table for weights 12, 18, and 22 when K is a cubic field, N is the character modulus
L7_12 = Lvalue_abs_squared(12,7,6)
L9_12 = Lvalue_abs_squared(12,9,6)
F9_12 = ((48600^2)/(81^(11/2)))
F7_12 = ((12600^2)/(49^(11/2)))
L7_18 = (Lvalue_abs_squared(18,7,9))
F7_18 = ((1)^2)/(49^(17/2))
L9_18= (Lvalue_abs_squared(18,9,9))
F9_18 = ((-7)^2)/(81^(17/2))
L7_22 = (Lvalue_abs_squared(22,7,11))
F7_22 = ((1)^2)/(49^(21/2))
L9_22= (Lvalue_abs_squared(22,9,11))
F9_22 = ((21)^2)/(81^(21/2))
print("Evidence for Weight 12, N = 7:",L7_12/F7_12)
print("Evidence for Weight 12, N = 9:",L9_12/F9_12)
print("Evidence for Weight 18, N = 7:",L7_18/F7_18)
print("Evidence for Weight 18, N = 9:",L9_18/F9_18)
print("Evidence for Weight 22, N = 7:",L7_22/F7_22)
print("Evidence for Weight 22, N = 9:",L9_22/F9_22)
# Out:
# Evidence for Weight 12, N = 7: (x, y) |--> 112896
# Evidence for Weight 12, N = 9: (x, y) |--> 112896
# Evidence for Weight 18, N = 7: (x, y) |--> 6594521776128000000
# Evidence for Weight 18, N = 9: (x, y) |--> 6594521776128000000
# Evidence for Weight 22, N = 7: (x, y) |--> 3057777166140702720000
# Evidence for Weight 22, N = 9: (x, y) |--> 3057777166140702720000

# %%
# Compute the ratio C from the Table for weight 12 in the degenerate case when K =  Q x Q(sqrt(D)) is a cubic field
F5 = ((15^2)/(5^(11/2)))
F13 = (((-(1320/8))^2)/(13^(11/2)))
F17 = (((-30)^2)/((17)^(11/2)))
F21 = (((5040/8)^2)/((21)^(11/2)))
Ratio5 = (LvalueQuadraticCase(12,5,6)*42)/F5
Ratio13 = (LvalueQuadraticCase(12,13,6)*42)/F13
Ratio17 = (LvalueQuadraticCase(12,17,6)*42)/F17
Ratio21 = (LvalueQuadraticCase(12,21,6)*42)/F21
print("Evidence for Quadratic case, Weight 12, D = 5:", Ratio5)
print("Evidence for Quadratic case, Weight 12, D = 13:", Ratio13)
print("Evidence for Quadratic case, Weight 12, D = 17:", Ratio17)
print("Evidence for Quadratic case, Weight 12, D = 21:", Ratio21)
# Out:
# Evidence for Quadratic case, Weight 12, D = 5: (x, y) |--> 112896
# Evidence for Quadratic case, Weight 12, D = 13: (x, y) |--> 112896
# Evidence for Quadratic case, Weight 12, D = 17: (x, y) |--> 112896
# Evidence for Quadratic case, Weight 12, D = 21: (x, y) |--> 112896
